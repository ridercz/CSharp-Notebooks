// %% [markdown]
// # Working with file system in C#

// %% [markdown]
// ## Working with files

// %% [markdown]
// ### Using the `System.IO.File` class
//
// The simplest way to work with file system files is to use static methods of the `System.IO.File` class. Use the `Exists` method to check if the file exists or not:

// %%
using System.IO;

// Let's create some file
File.WriteAllText("file1.txt", "Hello, world!");

// Check that file exists
Console.WriteLine($"file1.txt exists? {File.Exists("file1.txt")}");
Console.WriteLine($"file2.txt exists? {File.Exists("file2.txt")}");
// Out:
// file1.txt exists? True
// file2.txt exists? False

// %% [markdown]
// To rename or move the file, use the `Move` method. If the new file already exists, it will throw `IOException`:

// %%
// Rename the file
Console.WriteLine("Renaming file...");
File.Move("file1.txt", "file2.txt");
Console.WriteLine($"file1.txt exists? {File.Exists("file1.txt")}");
Console.WriteLine($"file2.txt exists? {File.Exists("file2.txt")}");
// Out:
// Renaming file...
// file1.txt exists? False
// file2.txt exists? True

// %% [markdown]
// To copy the file, use the `Copy` method. Again, it throws `IOException` if the destination file already exists:

// %%
// Copy the file
Console.WriteLine("Copying file...");
File.Copy("file2.txt", "file1.txt");
Console.WriteLine($"file1.txt exists? {File.Exists("file1.txt")}");
Console.WriteLine($"file2.txt exists? {File.Exists("file2.txt")}");
// Out:
// Copying file...
// file1.txt exists? True
// file2.txt exists? True

// %% [markdown]
// You can use static methods to read file properties and attributes:

// %%
Console.WriteLine($"Creation time:     {File.GetCreationTime("file1.txt")}");
Console.WriteLine($"Last write time:   {File.GetLastWriteTime("file1.txt")}");
Console.WriteLine($"Last access time:  {File.GetLastAccessTime("file1.txt")}");
Console.WriteLine($"Attributes:        {File.GetAttributes("file1.txt")}");
// Out:
// Creation time:     8/20/2023 1:42:12 AM
// Last write time:   8/20/2023 1:41:29 AM
// Last access time:  8/20/2023 1:42:12 AM
// Attributes:        Archive

// %% [markdown]
// We can set those properties as well - this is one of the reasons you could not trust file system metadata: anyone can modify them, at will.

// %%
File.SetCreationTime("file1.txt", new DateTime(2020, 1, 2, 3, 4, 5));
File.SetLastWriteTime("file1.txt", new DateTime(2020, 6, 7, 8, 9, 0));
File.SetLastAccessTime("file1.txt", new DateTime(2021, 2, 3, 4, 5, 6));
File.SetAttributes("file1.txt", FileAttributes.Hidden | FileAttributes.System);

Console.WriteLine($"Creation time:     {File.GetCreationTime("file1.txt")}");
Console.WriteLine($"Last write time:   {File.GetLastWriteTime("file1.txt")}");
Console.WriteLine($"Last access time:  {File.GetLastAccessTime("file1.txt")}");
Console.WriteLine($"Attributes:        {File.GetAttributes("file1.txt")}");
// Out:
// Creation time:     1/2/2020 3:04:05 AM
// Last write time:   6/7/2020 8:09:00 AM
// Last access time:  2/3/2021 4:05:06 AM
// Attributes:        Hidden, System

// %% [markdown]
// And of course, you can also delete the file. If you try to delete nonexistent file, it will do not throw any exception.

// %%
File.Delete("file1.txt");
File.Delete("file2.txt");

Console.WriteLine($"file1.txt exists? {File.Exists("file1.txt")}");
Console.WriteLine($"file2.txt exists? {File.Exists("file2.txt")}");
// Out:
// file1.txt exists? False
// file2.txt exists? False

// %% [markdown]
// ### Using `System.IO.FileInfo` class
//
// If you plan to work more extensively with a single file, it might be preferable to use the `FileInfo` class. It conceptually represents the file and allows to work with its properties and contents.

// %%
var fi = new FileInfo("file.txt");
Console.WriteLine($"file.txt exists? {File.Exists("file.txt")}");
fi.Display();
// Out:
// file.txt exists? False
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>file.txt</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Length</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.IO.FileNotFoundException: Could not find file &#39;c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\file.txt&#39;.\r\nFile name: &#39;c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\file.txt&#39;\r\n   at System.IO.FileInfo.get_Length()\r\n   at lambda_method287(Closure, FileInfo)\r\n   at Micro...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Message</td><td><div class="dni-plaintext"><pre>Could not find file &#39;c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\file.txt&#39;.</pre></div></td></tr><tr><td>FileName</td><td><div class="dni-plaintext"><pre>c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\file.txt</pre></div></td></tr><tr><td>FusionLog</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>TargetSite</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Int64 get_Length()</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>get_Length</pre></div></td></tr><tr><td>DeclaringType</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.io.fileinfo?view=net-7.0">System.IO.FileInfo</a></span></td></tr><tr><td>ReflectedType</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.io.fileinfo?view=net-7.0">System.IO.FileInfo</a></span></td></tr><tr><td>MemberType</td><td><span>Method</span></td></tr><tr><td>MetadataToken</td><td><div class="dni-plaintext"><pre>100689860</pre></div></td></tr><tr><td>Module</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.Private.CoreLib.dll</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>MDStreamVersion</td><td><div class="dni-plaintext"><pre>131072</pre></div></td></tr><tr><td>FullyQualifiedName</td><td><div class="dni-plaintext"><pre>C:\Program Files\dotnet\shared\Microsoft.NETCore.App\7.0.10\System.Private.CoreLib.dll</pre></div></td></tr><tr><td>ModuleVersionId</td><td><div class="dni-plaintext"><pre>b34296d7-545f-4a54-bda0-41aecea156b4</pre></div></td></tr><tr><td>MetadataToken</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>ScopeName</td><td><div class="dni-plaintext"><pre>System.Private.CoreLib.dll</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>System.Private.CoreLib.dll</pre></div></td></tr><tr><td>Assembly</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.Private.CoreLib, Version=7.0.0.0, Culture=neutral, PublicKeyToken=7cec85d7bea7798e</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>CodeBase</td><td><div class="dni-plaintext"><pre>file:///C:/Program Files/dotnet/shared/Microsoft.NETCore.App/7.0.10/System.Private.CoreLib.dll</pre></div></td></tr><tr><td>FullName</td><td><div class="dni-plaintext"><pre>System.Private.CoreLib, Version=7.0.0.0, Culture=neutral, PublicKeyToken=7cec85d7bea7798e</pre></div></td></tr><tr><td>EntryPoint</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>DefinedTypes</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td>Microsoft.CodeAnalysis.EmbeddedAttribute</td></tr><tr><td>1</td><td>System.Runtime.CompilerServices.IsUnmanagedAttribute</td></tr><tr><td>2</td><td>System.Runtime.CompilerServices.NullableAttribute</td></tr><tr><td>3</td><td>System.Runtime.CompilerServices.NullableContextAttribute</td></tr><tr><td>4</td><td>System.Runtime.CompilerServices.NullablePublicOnlyAttribute</td></tr><tr><td>5</td><td>System.Runtime.CompilerServices.ScopedRefAttribute</td></tr><tr><td>6</td><td>System.Runtime.CompilerServices.RefSafetyRulesAttribute</td></tr><tr><t ...

// %% [markdown]
// Creating instance of `FileInfo` does not create the file itself. You can use

// %%
using(var writer = fi.CreateText()) {
    writer.WriteLine("Hello, world!");
}
fi.Display();
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>file.txt</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Length</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.IO.FileNotFoundException: Could not find file &#39;c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\file.txt&#39;.\r\nFile name: &#39;c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\file.txt&#39;\r\n   at System.IO.FileInfo.get_Length()\r\n   at lambda_method287(Closure, FileInfo)\r\n   at Micro...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Message</td><td><div class="dni-plaintext"><pre>Could not find file &#39;c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\file.txt&#39;.</pre></div></td></tr><tr><td>FileName</td><td><div class="dni-plaintext"><pre>c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\file.txt</pre></div></td></tr><tr><td>FusionLog</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>TargetSite</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Int64 get_Length()</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>get_Length</pre></div></td></tr><tr><td>DeclaringType</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.io.fileinfo?view=net-7.0">System.IO.FileInfo</a></span></td></tr><tr><td>ReflectedType</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.io.fileinfo?view=net-7.0">System.IO.FileInfo</a></span></td></tr><tr><td>MemberType</td><td><span>Method</span></td></tr><tr><td>MetadataToken</td><td><div class="dni-plaintext"><pre>100689860</pre></div></td></tr><tr><td>Module</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.Private.CoreLib.dll</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>MDStreamVersion</td><td><div class="dni-plaintext"><pre>131072</pre></div></td></tr><tr><td>FullyQualifiedName</td><td><div class="dni-plaintext"><pre>C:\Program Files\dotnet\shared\Microsoft.NETCore.App\7.0.10\System.Private.CoreLib.dll</pre></div></td></tr><tr><td>ModuleVersionId</td><td><div class="dni-plaintext"><pre>b34296d7-545f-4a54-bda0-41aecea156b4</pre></div></td></tr><tr><td>MetadataToken</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>ScopeName</td><td><div class="dni-plaintext"><pre>System.Private.CoreLib.dll</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>System.Private.CoreLib.dll</pre></div></td></tr><tr><td>Assembly</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.Private.CoreLib, Version=7.0.0.0, Culture=neutral, PublicKeyToken=7cec85d7bea7798e</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>CodeBase</td><td><div class="dni-plaintext"><pre>file:///C:/Program Files/dotnet/shared/Microsoft.NETCore.App/7.0.10/System.Private.CoreLib.dll</pre></div></td></tr><tr><td>FullName</td><td><div class="dni-plaintext"><pre>System.Private.CoreLib, Version=7.0.0.0, Culture=neutral, PublicKeyToken=7cec85d7bea7798e</pre></div></td></tr><tr><td>EntryPoint</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>DefinedTypes</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td>Microsoft.CodeAnalysis.EmbeddedAttribute</td></tr><tr><td>1</td><td>System.Runtime.CompilerServices.IsUnmanagedAttribute</td></tr><tr><td>2</td><td>System.Runtime.CompilerServices.NullableAttribute</td></tr><tr><td>3</td><td>System.Runtime.CompilerServices.NullableContextAttribute</td></tr><tr><td>4</td><td>System.Runtime.CompilerServices.NullablePublicOnlyAttribute</td></tr><tr><td>5</td><td>System.Runtime.CompilerServices.ScopedRefAttribute</td></tr><tr><td>6</td><td>System.Runtime.CompilerServices.RefSafetyRulesAttribute</td></tr><tr><t ...

// %% [markdown]
// This is weird... The file exists, but the `FileInfo` class says it does not! The reason is that the class will cache its properties. Once you'll ask for some property value, it will be cached and won't change anymore. You have to manually call `Refresh` to refresh the values:

// %%
fi.Refresh();
fi.Display();
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>file.txt</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Length</td><td><div class="dni-plaintext"><pre>15</pre></div></td></tr><tr><td>DirectoryName</td><td><div class="dni-plaintext"><pre>c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts</pre></div></td></tr><tr><td>Directory</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\Users\Altair\Source\Repos\CSharp-Notebooks</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\Users\Altair\Source\Repos</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\Users\Altair\Source</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\Users\Altair</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td>c:\Users</td></tr><tr><td>Root</td><td>c:\</td></tr><tr><td>FullName</td><td>c:\Users\Altair</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>Altair</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>8/13/2022 5:00:19 PM</td></tr><tr><td>CreationTimeUtc</td><td>8/13/2022 3:00:19 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:47:28 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:47:28 PM</td></tr><tr><td>LastWriteTime</td><td>8/15/2023 12:13:50 PM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/15/2023 10:13:50 AM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Directory</td></tr></tbody></table></div></details></td></tr><tr><td>Root</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Root</td><td>c:\</td></tr><tr><td>FullName</td><td>c:\</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>c:\</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>6/5/2021 2:01:25 PM</td></tr><tr><td>CreationTimeUtc</td><td>6/5/2021 12:01:25 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:47:28 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:47:28 PM</td></tr><tr><td>LastWriteTime</td><td>8/19/2023 11:14:23 PM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/19/2023 9:14:23 PM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Hidden, System, Directory</td></tr></tbody></table></div></details></td></tr><tr><td>FullName</td><td><div class="dni-plaintext"><pre>c:\Users\Altair\Source</pre></div></td></tr><tr><td>Extension</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Source</pre></div></td></tr><tr><td>Exists</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>CreationTime</td><td><span>2022-08-13 18:32:41Z</span></td></tr><tr><td>CreationTimeUtc</td><td><span>2022-08-13 16:32:41Z</span></td></tr><tr><td>LastAccessTime</td><td><span>2023-08-20 01:47:08Z</span></td></tr><tr><td>LastAccessTimeUtc</td><td><span>2023-08-19 23:47:08Z</span></td></tr><tr><td>LastWriteTime</td><td><span>2022-08-13 18:32:41Z</span></td></tr><tr><td>LastWriteTimeUtc</td><td><span>2022-08-13 16:32:41 ...

// %% [markdown]
// There are some exceptions. If you use methods and properties of the `FileInfo` class itself to manipulate the file, it will refresh the metadata:

// %%
Console.WriteLine("Moving file...");
fi.MoveTo("new.txt");
fi.Display();

Console.WriteLine("Deleting file...");
fi.Delete();
fi.Display();
// Out:
// Moving file...
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>new.txt</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Length</td><td><div class="dni-plaintext"><pre>15</pre></div></td></tr><tr><td>DirectoryName</td><td><div class="dni-plaintext"><pre>c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts</pre></div></td></tr><tr><td>Directory</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\Users\Altair\Source\Repos\CSharp-Notebooks</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\Users\Altair\Source\Repos</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\Users\Altair\Source</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\Users\Altair</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td>c:\Users</td></tr><tr><td>Root</td><td>c:\</td></tr><tr><td>FullName</td><td>c:\Users\Altair</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>Altair</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>8/13/2022 5:00:19 PM</td></tr><tr><td>CreationTimeUtc</td><td>8/13/2022 3:00:19 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:48:08 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:48:08 PM</td></tr><tr><td>LastWriteTime</td><td>8/15/2023 12:13:50 PM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/15/2023 10:13:50 AM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Directory</td></tr></tbody></table></div></details></td></tr><tr><td>Root</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>c:\</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Root</td><td>c:\</td></tr><tr><td>FullName</td><td>c:\</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>c:\</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>6/5/2021 2:01:25 PM</td></tr><tr><td>CreationTimeUtc</td><td>6/5/2021 12:01:25 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:48:08 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:48:08 PM</td></tr><tr><td>LastWriteTime</td><td>8/19/2023 11:14:23 PM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/19/2023 9:14:23 PM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Hidden, System, Directory</td></tr></tbody></table></div></details></td></tr><tr><td>FullName</td><td><div class="dni-plaintext"><pre>c:\Users\Altair\Source</pre></div></td></tr><tr><td>Extension</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Source</pre></div></td></tr><tr><td>Exists</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>CreationTime</td><td><span>2022-08-13 18:32:41Z</span></td></tr><tr><td>CreationTimeUtc</td><td><span>2022-08-13 16:32:41Z</span></td></tr><tr><td>LastAccessTime</td><td><span>2023-08-20 01:48:08Z</span></td></tr><tr><td>LastAccessTimeUtc</td><td><span>2023-08-19 23:48:08Z</span></td></tr><tr><td>LastWriteTime</td><td><span>2022-08-13 18:32:41Z</span></td></tr><tr><td>LastWriteTimeUtc</td><td><span>2022-08-13 16:32:41Z ...
// Deleting file...
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>new.txt</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Length</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.IO.FileNotFoundException: Could not find file &#39;c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\new.txt&#39;.\r\nFile name: &#39;c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\new.txt&#39;\r\n   at System.IO.FileInfo.get_Length()\r\n   at lambda_method287(Closure, FileInfo)\r\n   at Microso...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Message</td><td><div class="dni-plaintext"><pre>Could not find file &#39;c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\new.txt&#39;.</pre></div></td></tr><tr><td>FileName</td><td><div class="dni-plaintext"><pre>c:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\new.txt</pre></div></td></tr><tr><td>FusionLog</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>TargetSite</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Int64 get_Length()</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>get_Length</pre></div></td></tr><tr><td>DeclaringType</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.io.fileinfo?view=net-7.0">System.IO.FileInfo</a></span></td></tr><tr><td>ReflectedType</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.io.fileinfo?view=net-7.0">System.IO.FileInfo</a></span></td></tr><tr><td>MemberType</td><td><span>Method</span></td></tr><tr><td>MetadataToken</td><td><div class="dni-plaintext"><pre>100689860</pre></div></td></tr><tr><td>Module</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.Private.CoreLib.dll</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>MDStreamVersion</td><td><div class="dni-plaintext"><pre>131072</pre></div></td></tr><tr><td>FullyQualifiedName</td><td><div class="dni-plaintext"><pre>C:\Program Files\dotnet\shared\Microsoft.NETCore.App\7.0.10\System.Private.CoreLib.dll</pre></div></td></tr><tr><td>ModuleVersionId</td><td><div class="dni-plaintext"><pre>b34296d7-545f-4a54-bda0-41aecea156b4</pre></div></td></tr><tr><td>MetadataToken</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>ScopeName</td><td><div class="dni-plaintext"><pre>System.Private.CoreLib.dll</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>System.Private.CoreLib.dll</pre></div></td></tr><tr><td>Assembly</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.Private.CoreLib, Version=7.0.0.0, Culture=neutral, PublicKeyToken=7cec85d7bea7798e</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>CodeBase</td><td><div class="dni-plaintext"><pre>file:///C:/Program Files/dotnet/shared/Microsoft.NETCore.App/7.0.10/System.Private.CoreLib.dll</pre></div></td></tr><tr><td>FullName</td><td><div class="dni-plaintext"><pre>System.Private.CoreLib, Version=7.0.0.0, Culture=neutral, PublicKeyToken=7cec85d7bea7798e</pre></div></td></tr><tr><td>EntryPoint</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>DefinedTypes</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td>Microsoft.CodeAnalysis.EmbeddedAttribute</td></tr><tr><td>1</td><td>System.Runtime.CompilerServices.IsUnmanagedAttribute</td></tr><tr><td>2</td><td>System.Runtime.CompilerServices.NullableAttribute</td></tr><tr><td>3</td><td>System.Runtime.CompilerServices.NullableContextAttribute</td></tr><tr><td>4</td><td>System.Runtime.CompilerServices.NullablePublicOnlyAttribute</td></tr><tr><td>5</td><td>System.Runtime.CompilerServices.ScopedRefAttribute</td></tr><tr><td>6</td><td>System.Runtime.CompilerServices.RefSafetyRulesAttribute</td></tr><tr><td>7 ...

// %% [markdown]
// ## Working with directories
//
// Although the Windows GUI uses the term _folders_, they are still called _directories_ in C#.

// %% [markdown]
// ### Using the `System.IO.Directory` class
//
// The `Directory` class is equivalent to the `File` class. It has bunch of static methods to work with directories. You can create whole path using the `CreateDirectory` method:

// %%
Directory.CreateDirectory(@"C:\Demo\ABC\DEF");
Console.WriteLine($"Directory exists? {Directory.Exists(@"C:\Demo\ABC\DEF")}");
// Out:
// Directory exists? True

// %% [markdown]
// Deleting it is more complicated. By default, the `Delete` method deletes only empty directory. If the directory contains other directories or files, `IOException` is thrown:

// %%
Directory.Delete(@"C:\Demo\");
// Out:
// System.IO.IOException: The directory is not empty. : 'C:\Demo\'
//
//    at System.IO.FileSystem.RemoveDirectoryInternal(String fullPath, Boolean topLevel, Boolean allowDirectoryNotEmpty)
//
//    at System.IO.FileSystem.RemoveDirectory(String fullPath, Boolean recursive)
//
//    at Submission#13.<<Initialize>>d__0.MoveNext()
//
// --- End of stack trace from previous location ---
//
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

// %% [markdown]
// You can use other overload of Delete method to perform the recursive deletion:

// %%
Directory.Delete(@"C:\Demo\", recursive: true);
Console.WriteLine($"Directory exists? {Directory.Exists(@"C:\Demo\ABC\DEF")}");
// Out:
// Directory exists? False

// %% [markdown]
// In contrast to deleting a file, deleting a non-existing directory throws an `DirectoryNotFoundException`:

// %%
Directory.Delete(@"C:\Demo\");
// Out:
// System.IO.DirectoryNotFoundException: Could not find a part of the path 'C:\Demo\'.
//
//    at System.IO.FileSystem.RemoveDirectoryInternal(String fullPath, Boolean topLevel, Boolean allowDirectoryNotEmpty)
//
//    at System.IO.FileSystem.RemoveDirectory(String fullPath, Boolean recursive)
//
//    at Submission#15.<<Initialize>>d__0.MoveNext()
//
// --- End of stack trace from previous location ---
//
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

// %% [markdown]
// You can also list all files in the directory:

// %%
var files = Directory.GetFiles(@"C:\Users\Altair\Source\Repos\CSharp-Notebooks\");
files.DisplayTable();
// Out:
// <table><thead><tr><td><span>value</span></td></tr></thead><tbody><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\CODE_OF_CONDUCT.md</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\CSharp-Notebooks.code-workspace</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\LICENSE</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\README.md</td></tr></tbody></table><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %% [markdown]
// Various overloads allow you to filter the files using a wildcard mask or perform the search recursively:

// %%
var files = Directory.GetFiles(
    @"C:\Users\Altair\Source\Repos\CSharp-Notebooks\", 
    "*.ipynb", 
    new EnumerationOptions { RecurseSubdirectories = true}
);
files.DisplayTable();
// Out:
// <table><thead><tr><td><span>value</span></td></tr></thead><tbody><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\Files.ipynb</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\FileSystem.ipynb</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\GZIP.ipynb</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\OTP.ipynb</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\Path.ipynb</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\RNG.ipynb</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts\ZIP.ipynb</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\HowTo\KurzyCNB.ipynb</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\Libraries\CsvHelper.ipynb</td></tr></tbody></table><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %% [markdown]
// The `GetFiles` method gets just filenames of just files. There is `GetFileSystemEntries` method, which will get names of files and folders.

// %%
var fse = Directory.GetFileSystemEntries(@"C:\Users\Altair\Source\Repos\CSharp-Notebooks");
fse.DisplayTable();
// Out:
// <table><thead><tr><td><span>value</span></td></tr></thead><tbody><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\.git</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\.vscode</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\CODE_OF_CONDUCT.md</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\Concepts</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\CSharp-Notebooks.code-workspace</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\HowTo</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\Libraries</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\LICENSE</td></tr><tr><td>C:\Users\Altair\Source\Repos\CSharp-Notebooks\README.md</td></tr></tbody></table><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %% [markdown]
// > _Please note:_ You'll get names, just that. There is no way to find out which of these are files and which are directories. The convention that files have extensions and directories don't is just an convention. The `LICENSE` above is a file and `.git` is a directory.

// %% [markdown]
// ### Using the `System.IO.DirectoryInfo` class
//
// The `DirectoryInfo` class is equivalent to `FileInfo` class, just works with directories:

// %%
var di = new DirectoryInfo(@"C:\Users\Altair\Source\Repos\CSharp-Notebooks");
di.Display();
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source\Repos\CSharp-Notebooks</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source\Repos</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Root</td><td>C:\</td></tr><tr><td>FullName</td><td>C:\</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>C:\</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>6/5/2021 2:01:25 PM</td></tr><tr><td>CreationTimeUtc</td><td>6/5/2021 12:01:25 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:52:55 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:52:55 PM</td></tr><tr><td>LastWriteTime</td><td>8/20/2023 1:49:54 AM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/19/2023 11:49:54 PM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Hidden, System, Directory</td></tr></tbody></table></div></details></td></tr><tr><td>Root</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Root</td><td>C:\</td></tr><tr><td>FullName</td><td>C:\</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>C:\</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>6/5/2021 2:01:25 PM</td></tr><tr><td>CreationTimeUtc</td><td>6/5/2021 12:01:25 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:52:55 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:52:55 PM</td></tr><tr><td>LastWriteTime</td><td>8/20/2023 1:49:54 AM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/19/2023 11:49:54 PM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Hidden, System, Directory</td></tr></tbody></table></div></details></td></tr><tr><td>FullName</td><td><div class="dni-plaintext"><pre>C:\Users</pre></div></td></tr><tr><td>Extension</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Users</pre></div></td></tr><tr><td>Exists</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>CreationTime</td><td><span>2022-05-07 07:17:22Z</span></td></tr><tr><td>CreationTimeUtc</td><td><span>2022-05-07 05:17:22Z</span></td></tr><tr><td>LastAccessTime</td><td><span>2023-08-20 01:52:43Z</span></td></tr><tr><td>LastAccessTimeUtc</td><td><span>2023-08-19 23:52:43Z</span></td></tr><tr><td>LastWriteTime</td><td><span>2022-08-13 17:00:19Z</span></td></tr><tr><td>LastWriteTimeUtc</td><td><span>2022-08-13 15:00:19Z</span></td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td><span>-1</span></td></tr><tr><td>Attributes</td><td><span>ReadOnly, Directory</span></td></tr></tbo ...

// %% [markdown]
// It can also list files as `FileInfo` classes and directories as `DirectoryInfo`:

// %%
di.GetFiles().Display();
di.GetDirectories().Display();
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source\Repos\CSharp-Notebooks\CODE_OF_CONDUCT.md</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Length</td><td><div class="dni-plaintext"><pre>258</pre></div></td></tr><tr><td>DirectoryName</td><td><div class="dni-plaintext"><pre>C:\Users\Altair\Source\Repos\CSharp-Notebooks</pre></div></td></tr><tr><td>Directory</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source\Repos\CSharp-Notebooks</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source\Repos</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td>C:\Users</td></tr><tr><td>Root</td><td>C:\</td></tr><tr><td>FullName</td><td>C:\Users\Altair</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>Altair</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>8/13/2022 5:00:19 PM</td></tr><tr><td>CreationTimeUtc</td><td>8/13/2022 3:00:19 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:53:34 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:53:34 PM</td></tr><tr><td>LastWriteTime</td><td>8/15/2023 12:13:50 PM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/15/2023 10:13:50 AM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Directory</td></tr></tbody></table></div></details></td></tr><tr><td>Root</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Root</td><td>C:\</td></tr><tr><td>FullName</td><td>C:\</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>C:\</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>6/5/2021 2:01:25 PM</td></tr><tr><td>CreationTimeUtc</td><td>6/5/2021 12:01:25 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:53:35 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:53:35 PM</td></tr><tr><td>LastWriteTime</td><td>8/20/2023 1:49:54 AM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/19/2023 11:49:54 PM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Hidden, System, Directory</td></tr></tbody></table></div></details></td></tr><tr><td>FullName</td><td><div class="dni-plaintext"><pre>C:\Users\Altair\Source</pre></div></td></tr><tr><td>Extension</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Source</pre></div></td></tr><tr><td>Exists</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>CreationTime</td><td><span>2022-08-13 18:32:41Z</span></td></tr><tr><td>CreationTimeUtc</td><td><span>2022-08-13 16:32:41Z</span></td></tr><tr><td>LastAccessTime</td><td><span>2023-08-20 01:53:11Z</span></td></tr><tr><td>LastAccessTimeUtc</td><td><span>2023-08-19 23:53:11Z</span></td></tr><tr><td>LastWriteTime</td><td><span>2022-08-13 18:32:41Z</span></td></tr><tr><td>LastWriteTimeUtc</td><td><span>2022-08-13 16:32:41Z</span></td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;< ...
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source\Repos\CSharp-Notebooks\.git</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source\Repos\CSharp-Notebooks</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source\Repos</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td>C:\Users</td></tr><tr><td>Root</td><td>C:\</td></tr><tr><td>FullName</td><td>C:\Users\Altair</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>Altair</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>8/13/2022 5:00:19 PM</td></tr><tr><td>CreationTimeUtc</td><td>8/13/2022 3:00:19 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:53:34 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:53:34 PM</td></tr><tr><td>LastWriteTime</td><td>8/15/2023 12:13:50 PM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/15/2023 10:13:50 AM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Directory</td></tr></tbody></table></div></details></td></tr><tr><td>Root</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Root</td><td>C:\</td></tr><tr><td>FullName</td><td>C:\</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>C:\</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>6/5/2021 2:01:25 PM</td></tr><tr><td>CreationTimeUtc</td><td>6/5/2021 12:01:25 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:53:35 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:53:35 PM</td></tr><tr><td>LastWriteTime</td><td>8/20/2023 1:49:54 AM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/19/2023 11:49:54 PM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Hidden, System, Directory</td></tr></tbody></table></div></details></td></tr><tr><td>FullName</td><td><div class="dni-plaintext"><pre>C:\Users\Altair\Source</pre></div></td></tr><tr><td>Extension</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Source</pre></div></td></tr><tr><td>Exists</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>CreationTime</td><td><span>2022-08-13 18:32:41Z</span></td></tr><tr><td>CreationTimeUtc</td><td><span>2022-08-13 16:32:41Z</span></td></tr><tr><td>LastAccessTime</td><td><span>2023-08-20 01:53:11Z</span></td></tr><tr><td>LastAccessTimeUtc</td><td><span>2023-08-19 23:53:11Z</span></td></tr><tr><td>LastWriteTime</td><td><span>2022-08-13 18:32:41Z</span></td></tr><tr><td>LastWriteTimeUtc</td><td><span>2022-08-13 16:32:41Z</span></td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td><span>-1</span></td></tr><tr><td>Attributes</td><td><span>Directory</span></td></tr></tbody></table></div></details></td></tr><tr><td>Root</td><td><details class="dni-treeview" ...

// %% [markdown]
// The `GetFileSystemInfos` will return both files and directories:

// %%
di.GetFileSystemInfos().Display();
// Out:
// <table><thead><tr><th><i>index</i></th><th><i>type</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.io.directoryinfo?view=net-7.0">System.IO.DirectoryInfo</a></span></td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source\Repos\CSharp-Notebooks\.git</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source\Repos\CSharp-Notebooks</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source\Repos</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair\Source</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\Users\Altair</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td>C:\Users</td></tr><tr><td>Root</td><td>C:\</td></tr><tr><td>FullName</td><td>C:\Users\Altair</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>Altair</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>8/13/2022 5:00:19 PM</td></tr><tr><td>CreationTimeUtc</td><td>8/13/2022 3:00:19 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:53:41 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:53:41 PM</td></tr><tr><td>LastWriteTime</td><td>8/15/2023 12:13:50 PM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/15/2023 10:13:50 AM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Directory</td></tr></tbody></table></div></details></td></tr><tr><td>Root</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>C:\</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Parent</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Root</td><td>C:\</td></tr><tr><td>FullName</td><td>C:\</td></tr><tr><td>Extension</td><td></td></tr><tr><td>Name</td><td>C:\</td></tr><tr><td>Exists</td><td>True</td></tr><tr><td>CreationTime</td><td>6/5/2021 2:01:25 PM</td></tr><tr><td>CreationTimeUtc</td><td>6/5/2021 12:01:25 PM</td></tr><tr><td>LastAccessTime</td><td>8/20/2023 1:53:45 AM</td></tr><tr><td>LastAccessTimeUtc</td><td>8/19/2023 11:53:45 PM</td></tr><tr><td>LastWriteTime</td><td>8/20/2023 1:49:54 AM</td></tr><tr><td>LastWriteTimeUtc</td><td>8/19/2023 11:49:54 PM</td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td>-1</td></tr><tr><td>Attributes</td><td>Hidden, System, Directory</td></tr></tbody></table></div></details></td></tr><tr><td>FullName</td><td><div class="dni-plaintext"><pre>C:\Users\Altair\Source</pre></div></td></tr><tr><td>Extension</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Source</pre></div></td></tr><tr><td>Exists</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>CreationTime</td><td><span>2022-08-13 18:32:41Z</span></td></tr><tr><td>CreationTimeUtc</td><td><span>2022-08-13 16:32:41Z</span></td></tr><tr><td>LastAccessTime</td><td><span>2023-08-20 01:53:11Z</span></td></tr><tr><td>LastAccessTimeUtc</td><td><span>2023-08-19 23:53:11Z</span></td></tr><tr><td>LastWriteTime</td><td><span>2022-08-13 18:32:41Z</span></td></tr><tr><td>LastWriteTimeUtc</td><td><span>2022-08-13 16:32:41Z</span></td></tr><tr><td>LinkTarget</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>UnixFileMode</td><td><span>-1</span></td></ ...

// %% [markdown]
// > _Please note:_ These methods return arrays. There are also `EnumerateFiles`, `EnumerateDirectories` and `EnumerateFileSystemInfos`, that return `IEnumerable` of the appropriate type. It may be better to use them, if you don't need the entire list.
